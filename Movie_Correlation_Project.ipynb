# %%
#import libreies

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

#Read in the data

df =pd.read_csv('movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    missing_count = df[col].isnull().sum()  # นับจำนวน NaN
    total_count = len(df[col])  # จำนวนทั้งหมด
    pct_missing = (missing_count / total_count) * 100  # คำนวณ %
    
    print(f"{col}: {missing_count} missing values ({pct_missing:.2f}%)")
# Out:
# name: 0 missing values (0.00%)
# rating: 77 missing values (1.00%)
# genre: 0 missing values (0.00%)
# year: 0 missing values (0.00%)
# released: 2 missing values (0.03%)
# score: 3 missing values (0.04%)
# votes: 3 missing values (0.04%)
# director: 0 missing values (0.00%)
# writer: 3 missing values (0.04%)
# star: 1 missing values (0.01%)
# country: 3 missing values (0.04%)
# budget: 2171 missing values (28.31%)
# gross: 189 missing values (2.46%)
# company: 17 missing values (0.22%)
# runtime: 4 missing values (0.05%)

# %%
df = df.dropna(axis=0)

# %%
print(df.isnull().sum(),'\n')
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
#Check the data types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Chang data types of columns
df['budget'] = df['budget'].fillna(0).astype('int64')
df['gross'] = df['gross'].fillna(0).astype('int64')

# %%
df.head(40)
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# 5                                  Friday the 13th      R     Horror  1980
# 6                               The Blues Brothers      R     Action  1980
# 7                                      Raging Bull      R  Biography  1980
# 8                                      Superman II     PG     Action  1980
# 9                                  The Long Riders      R  Biography  1980
# 10                           Any Which Way You Can     PG     Action  1980
# ...

# %%
# clean the data (create year correct column)

df['yearcorrect'] = df['released'].str.extract(r'(\d{4})')

df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df['yearcorrect'] = df['yearcorrect'].fillna(0).astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5421 entries, 0 to 7652
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         5421 non-null   object
#  1   rating       5421 non-null   object
#  2   genre        5421 non-null   object
#  3   year         5421 non-null   int64
#  4   released     5421 non-null   object
#  5   score        5421 non-null   float64
#  6   votes        5421 non-null   float64
#  7   director     5421 non-null   object
#  8   writer       5421 non-null   object
#  9   star         5421 non-null   object
#  10  country      5421 non-null   object
#  11  budget       5421 non-null   int64
#  12  gross        5421 non-null   int64
#  13  company      5421 non-null   object
#  14  runtime      5421 non-null   float64
#  15  yearcorrect  5421 non-null   int64
# dtypes: float64(3), int64(4), object(9)
# memory usage: 720.0+ KB

# %%
df.sort_values(by=['gross'], inplace = False, ascending= False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
pd.set_option('display.max_rows',20)

# %%
# Drop any duplicates

df['company'].drop_duplicates().sort_values(ascending= False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 385                        1818 Productions
# 2929                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Budget high correlation
# company high correlation

# %%
# Scatter plot with budget vs gross


plt.figure(figsize=(10,6))  # กำหนดขนาดของกราฟ

plt.scatter(df['budget'], df['gross'], alpha=0.5)  # เพิ่ม alpha ให้จุดโปร่งแสง

plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Earnings')

plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Plot budget vs gross using seaborn
# พล็อต scatter plot + regression line
sns.regplot(x="budget", y="gross", data=df, scatter_kws={"color": "red"}, line_kws={"color": "blue"})

# เพิ่มชื่อแกน
plt.xlabel("Budget for Film")
plt.ylabel("Gross Earnings")
plt.title("Relationship between Budget for Film and Gross Earnings")

# แสดงกราฟ
plt.show()

# %%
#Let's start looking at correlation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5421 entries, 0 to 7652
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         5421 non-null   object
#  1   rating       5421 non-null   object
#  2   genre        5421 non-null   object
#  3   year         5421 non-null   int64
#  4   released     5421 non-null   object
#  5   score        5421 non-null   float64
#  6   votes        5421 non-null   float64
#  7   director     5421 non-null   object
#  8   writer       5421 non-null   object
#  9   star         5421 non-null   object
#  10  country      5421 non-null   object
#  11  budget       5421 non-null   int64
#  12  gross        5421 non-null   int64
#  13  company      5421 non-null   object
#  14  runtime      5421 non-null   float64
#  15  yearcorrect  5421 non-null   int64
# dtypes: float64(3), int64(4), object(9)
# memory usage: 720.0+ KB

# %%
#  ค่า Correlation ที่ได้จะอยู่ระหว่าง -1 ถึง 1

# ใกล้ 1 → ตัวแปรสองตัวมีความสัมพันธ์ทางบวกสูง (เพิ่มขึ้นด้วยกัน)
# ใกล้ -1 → ตัวแปรสองตัวมีความสัมพันธ์ทางลบสูง (ตัวหนึ่งเพิ่ม อีกตัวลด)
# ใกล้ 0 → ไม่มีความสัมพันธ์

# %%
df.corr(numeric_only= 'True')

# votes กับ gross → 0.614751 → มีความสัมพันธ์เชิงบวกสูง (จำนวนโหวตมีผลต่อรายได้)
# budget กับ gross → 0.740247 → มีความสัมพันธ์เชิงบวกสูงมาก (งบประมาณสูง รายได้ก็สูง)
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross        0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime      0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorrect  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#              yearcorrect
# year            0.998726
# score           0.061923
# votes           0.203098
# budget          0.320312
# gross           0.268721
# runtime         0.075294
# yearcorrect     1.000000

# %%
df.corr(numeric_only= 'True', method='kendall') #pearsom #kendall #spearman
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score        0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes        0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget       0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross        0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime      0.064824  0.292254  0.205344  0.231278  0.176979  1.000000
# yearcorrect  0.991304  0.043400  0.293044  0.213719  0.232372  0.064793
#
#              yearcorrect
# year            0.991304
# score           0.043400
# votes           0.293044
# budget          0.213719
# gross           0.232372
# runtime         0.064793
# yearcorrect     1.000000

# %%
# annot=True → แสดงค่าตัวเลขบน heatmap
# cmap="coolwarm" → ใช้ coolwarm colormap (สีฟ้าแทนค่าลบ, สีแดงแทนค่าบวก)
# fmt=".3f" → กำหนดให้ค่าความสัมพันธ์แสดงทศนิยม 3 ตำแหน่ง

# %%
correlation_matrix = df.corr(numeric_only=True, method='pearson')
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".3f")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
#Looks at company
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# ใช้ .copy() เพื่อให้ df_numerized ไม่ไปแก้ไข df
# ใช้ .select_dtypes(include=['object']) เพื่อเลือกเฉพาะคอลัมน์ที่เป็น object

df_numerized = df.copy()  # ป้องกันการเปลี่ยนแปลง df ต้นฉบับ

for col_name in df_numerized.select_dtypes(include=['object']).columns:
    df_numerized[col_name] = df_numerized[col_name].astype('category').cat.codes 
    # แปลงข้อความเป็นประเภท categoryและ แปลง category เป็นตัวเลข

df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1     3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2     3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3      204       4      4  1980      1127    7.7   221000.0       889    1413
# 4      732       6      4  1980      1170    7.3   108000.0       719     351
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7648   415       6      0  2020       904    6.6   140000.0        16    2390
# 7649  3556       4      0  2020       713    6.5   102000.0       852    2309
# 7650  1153       4      1  2020       904    5.6    53000.0      1809    2827
# 7651  3978       4      1  2020       758    6.8    42000.0       294    2091
# 7652  4090       3      0  2020       370    6.8     3700.0       746    1184
#
# ...

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
correlation_matrix = df_numerized.corr(numeric_only=True, method='pearson')
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".3f")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released    -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score        0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#                               ...
# yearcorrect  budget         0.320312
#              gross          0.268721
#              company       -0.018806
#              runtime        0.075294
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
pd.set_option('display.max_rows', None)  # แสดงทุกแถว
pd.set_option('display.max_columns', None)  # แสดงทุกคอลัมน์ (เผื่อไว้)
pd.set_option('display.expand_frame_repr', False)  # ป้องกันการตัดบรรทัด
print(corr_pairs)
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#              score          0.014450
#              votes          0.012615
#              director       0.015246
#              writer         0.012880
#              star          -0.006882
#              country       -0.025490
#              budget         0.023392
#              gross          0.005639
#              company        0.021697
#              runtime        0.010850
#              yearcorrect    0.025542
# rating       name          -0.029234
#              rating         1.000000
#              genre          0.147796
#              year           0.019499
#              released       0.018083
#              score          0.065983
#              votes          0.006031
#              director       0.014656
#              writer        -0.003149
# ...

# %%
sorted_pairs = corr_pairs.sort_values(ascending=False)  # เรียงค่าจากมากไปน้อย
sorted_pairs
# Out:
# name         name           1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# yearcorrect  yearcorrect    1.000000
#              year           0.998726
# year         yearcorrect    0.998726
# budget       gross          0.740247
# gross        budget         0.740247
#              votes          0.614751
# votes        gross          0.614751
# score        votes          0.474256
# votes        score          0.474256
# budget       votes          0.439675
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# gross        votes          0.614751
# votes        gross          0.614751
# gross        budget         0.740247
# budget       gross          0.740247
# year         yearcorrect    0.998726
# yearcorrect  year           0.998726
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# Votes and budget have the highest correlation to gross earning
# Company has low correlation
